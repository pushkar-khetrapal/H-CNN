# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.signal

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls 'gdrive/My Drive/left_fist.npy'
# Out:
# 'gdrive/My Drive/left_fist.npy'

# %%
left_fist = np.load('gdrive/My Drive/left_fist.npy')
right_fist = np.load('gdrive/My Drive/right_fist.npy')
both_fist = np.load('gdrive/My Drive/both_fist.npy')
both_feet = np.load('gdrive/My Drive/both_feet.npy')

# %%
left_fist = np.array(left_fist[:530])
right_fist = np.array(right_fist[:530])
both_fist = np.array(both_fist)
both_feet = np.array(both_feet)
print(left_fist.shape)
print(right_fist.shape)
print(both_fist.shape)
print(both_feet.shape)
# Out:
# (530, 64, 113)
# (530, 64, 113)
# (530, 64, 113)
# (530, 64, 113)

# %%
#plt.plot(left_fist[0][0])
#plt.show()
plt.plot(right_fist[0][0])
plt.show()
#plt.plot(np.fft.fft(both_fist[0][0])[:40])
plt.plot(np.fft.fft(left_fist[0][0])[:40])
plt.plot(np.fft.fft(right_fist[0][0])[:40])

#plt.plot(both_fist[0][0])
#plt.show()
#plt.plot(both_feet[0][0])
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(scipy.signal.welch(left_fist)[1][90][8])
plt.plot(scipy.signal.welch(right_fist)[1][90][8])
#plt.plot(both_fist[0][0])
#plt.plot(both_feet[0][0])
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 113, using nperseg = 113
#   .format(nperseg, input_length))
# /usr/local/lib/python3.6/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 113, using nperseg = 113
#   .format(nperseg, input_length))

# %%
print(abs(np.sum(left_fist[0][0] - right_fist[0][0])))
print(abs(np.sum(left_fist[0][0] - both_fist[0][0])))
print(abs(np.sum(left_fist[0][0] - both_feet[0][0])))
print(abs(np.sum(both_feet[0][0] - both_fist[0][0])))
# Out:
# 6.853359500868575e-07
# 1.6039158473338503e-05
# 3.0591367277883825e-05
# 1.4552208804545327e-05

# %%
events = np.zeros((2120,4))
ones = np.ones((530,))

# %%
# left fist
events[:530,0] = events[:530,0] + ones
# right fist
events[530:1060,1] = events[530:1060,1] + ones
# both fist 
events[1060:1590,2] = events[1060:1590,2] + ones
# both feet
events[1590:,3] = events[1590:,3] + ones

# %%
def preprocessing(data):
    mean = np.mean(data, axis = 0)    
    var = np.var(data, axis = 0)
    data = (data - mean)/var
    return data
#data_array = preprocessing(data)

# %%
# Power Spectral Density

# %%
import scipy
psd_left_fist = scipy.signal.welch(left_fist)[1][:,:,:40]
psd_right_fist = scipy.signal.welch(right_fist)[1][:,:,:40]
psd_both_fist = scipy.signal.welch(both_fist)[1][:,:,:40]
psd_both_feet = scipy.signal.welch(both_feet)[1][:,:,:40]
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/signal/spectral.py:1966: UserWarning: nperseg = 256 is greater than input length  = 113, using nperseg = 113
#   .format(nperseg, input_length))

# %%
psd_left_fist = psd_left_fist.reshape((530, 2560))
psd_right_fist = psd_right_fist.reshape((530, 2560))
psd_both_fist = psd_both_fist.reshape((530, 2560))
psd_both_feet = psd_both_feet.reshape((530, 2560))

# %%
psd_left_fist = preprocessing(psd_left_fist)
psd_right_fist = preprocessing(psd_right_fist)
psd_both_fist = preprocessing(psd_both_fist)
psd_both_feet = preprocessing(psd_both_feet)

# %%
plt.plot(psd_left_fist[0])

# %%
psd_data = np.concatenate((psd_left_fist, psd_right_fist, psd_both_fist, psd_both_feet), axis = 0)
psd_data.shape
# Out:
# (2120, 2560)

# %%
new_power_data = psd_data.reshape((2120, 2560, 1))
events.shape
# Out:
# (2120, 4)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler # Used for scaling of data
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import metrics
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import MaxPooling1D, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, BatchNormalization

# %%
x_train, x_test, y_train, y_test = train_test_split(new_power_data, events, test_size=0.3, random_state=42)
x_train.shape
# Out:
# (1484, 2560, 1)

# %%
def create_model():
    # create model
    model = Sequential()
    model.add(Conv1D(filters=50, kernel_size=11, activation='elu', input_shape=(2560, 1)))
    model.add(Conv1D(filters=15, kernel_size=3, activation='elu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(100, activation='elu'))
    model.add(Dropout(0.3))
    model.add(Dense(120, activation='elu'))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(Dense(15, activation='elu'))
    model.add(Dense(4, activation='softmax'))


    # Compile model
    model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['acc'])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 2550, 50)          600
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2548, 15)          2265
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 1274, 15)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 19110)             0
# _________________________________________________________________
# dense (Dense)                (None, 100)               1911100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               12120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 120)               480
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                1815
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 64
# =================================================================
# Total params: 1,928,444
# Trainable params: 1,928,204
# Non-trainable params: 240
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs=50)
# Out:
# Epoch 1/50
# 47/47 [==============================] - 8s 177ms/step - loss: 1.2808 - acc: 0.4865 - val_loss: 0.3730 - val_acc: 0.9057
# Epoch 2/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.3787 - acc: 0.8807 - val_loss: 0.2481 - val_acc: 0.9450
# Epoch 3/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.2085 - acc: 0.9495 - val_loss: 0.1775 - val_acc: 0.9450
# Epoch 4/50
# 47/47 [==============================] - 8s 171ms/step - loss: 0.1418 - acc: 0.9636 - val_loss: 0.1010 - val_acc: 0.9717
# Epoch 5/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0886 - acc: 0.9825 - val_loss: 0.0695 - val_acc: 0.9843
# Epoch 6/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0566 - acc: 0.9872 - val_loss: 0.0546 - val_acc: 0.9906
# Epoch 7/50
# 47/47 [==============================] - 8s 171ms/step - loss: 0.0586 - acc: 0.9858 - val_loss: 0.0455 - val_acc: 0.9843
# Epoch 8/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0390 - acc: 0.9939 - val_loss: 0.0710 - val_acc: 0.9780
# Epoch 9/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0488 - acc: 0.9892 - val_loss: 0.0643 - val_acc: 0.9858
# Epoch 10/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0383 - acc: 0.9879 - val_loss: 0.0669 - val_acc: 0.9764
# Epoch 11/50
# 47/47 [==============================] - 8s 174ms/step - loss: 0.0406 - acc: 0.9865 - val_loss: 0.0301 - val_acc: 0.9874
# Epoch 12/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0624 - acc: 0.9784 - val_loss: 0.0481 - val_acc: 0.9827
# Epoch 13/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0586 - acc: 0.9852 - val_loss: 0.0367 - val_acc: 0.9921
# Epoch 14/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.
50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0093 - acc: 0.9980 - val_loss: 0.0445 - val_acc: 0.9906
# Epoch 42/50
# 47/47 [==============================] - 8s 171ms/step - loss: 0.0225 - acc: 0.9919 - val_loss: 0.0483 - val_acc: 0.9937
# Epoch 43/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0288 - acc: 0.9879 - val_loss: 0.0701 - val_acc: 0.9874
# Epoch 44/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0098 - acc: 0.9973 - val_loss: 0.0663 - val_acc: 0.9858
# Epoch 45/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0072 - acc: 0.9980 - val_loss: 0.0666 - val_acc: 0.9874
# Epoch 46/50
# 47/47 [==============================] - 8s 171ms/step - loss: 0.0053 - acc: 0.9987 - val_loss: 0.0567 - val_acc: 0.9858
# Epoch 47/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0039 - acc: 0.9993 - val_loss: 0.0393 - val_acc: 0.9906
# Epoch 48/50
# 47/47 [==============================] - 8s 170ms/step - loss: 0.0044 - acc: 0.9987 - val_loss: 0.0397 - val_acc: 0.9890
# Epoch 49/50
# 47/47 [==============================] - 8s 172ms/step - loss: 0.0096 - acc: 0.9966 - val_loss: 0.0311 - val_acc: 0.9906
# Epoch 50/50
# 47/47 [==============================] - 8s 173ms/step - loss: 0.0087 - acc: 0.9987 - val_loss: 0.0484 - val_acc: 0.9890

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
from sklearn.metrics import confusion_matrix
import tensorflow as tf
def result(x_test, y_test):
  y_pred = model.predict(x_test)
  y_classes = y_pred.argmax(axis=-1)
  label =  tf.keras.utils.to_categorical(np.asarray(y_classes)) 
  matrix = confusion_matrix(y_test.argmax(axis=1), label.argmax(axis=1))
  FP = np.sum(matrix.sum(axis=0) - np.diag(matrix))/4  
  FN = np.sum(matrix.sum(axis=1) - np.diag(matrix))/4
  TP = np.sum(np.diag(matrix))/4
  TN = np.sum(matrix.sum() - (FP + FN + TP))/4
  data = []
  # Overall accuracy
  accuracy = (TP+TN)/(TP+FP+FN+TN)
  data.append(accuracy)
  #Error
  error = (FP + FN)/(TP + TN + FN + FP)
  data.append(error)
  # Sensitivity, hit rate, recall, or true positive rate
  sensitivity = TP/(TP+FN)  
  data.append(sensitivity)
  # Specificity or true negative rate
  specificity = TN/(TN+FP)
  data.append(specificity)
  # Precision or positive predictive value
  precision = TP/(TP+FP)
  data.append(precision)
  # Fall out or false positive rate
  false_positive_rate = FP/(FP+TN)
  data.append(false_positive_rate)

  #F-score
  f_score = (2*(precision *sensitivity))/(precision  + sensitivity)
  data.append(f_score)
  # False discovery rate
  FDR = FP/(TP+FP)
  data.append(FDR)
  # Negative predictive value
  NPV = TN/(TN+FN)
  data.append(NPV)
  return data
test_results = result(x_test, y_test)
test_results
# Out:
# [0.9874804381846636,
#  0.012519561815336464,
#  0.9889937106918238,
#  0.9854847071021254,
#  0.9889937106918238,
#  0.014515292897874546,
#  0.9889937106918238,
#  0.0110062893081761,
#  0.9854847071021254]

# %%
train_results = result(x_train, y_train)
train_results
# Out:
# [1.0, 0.0, 1.0, 1.0, 1.0, 0.0, 1.0, 0.0, 1.0]
