# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import mne

# %%
def data_fetch(i, j):
    if i < 10:
        if j < 10:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S00{}/S00{}R0{}.edf'.format(i,i,j), preload = True)
        else:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S00{}/S00{}R{}.edf'.format(i,i,j), preload = True)
    elif i >= 10 and i < 100:
        if j < 10:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S0{}/S0{}R0{}.edf'.format(i,i,j), preload = True)
        else:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S0{}/S0{}R{}.edf'.format(i,i,j), preload = True)

    else:
        if j < 10:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S{}/S{}R0{}.edf'.format(i,i,j), preload = True)
        else:
            raw = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S{}/S{}R{}.edf'.format(i,i,j), preload = True)

            
    raw.rename_channels(lambda s: s.strip('.'))
    events_from_annot, event_dict = mne.events_from_annotations(raw)
    raw.set_eeg_reference("average", projection = True)
    
    #montages
    montage = mne.channels.read_montage("standard_1020")
    raw.set_montage(montage)
    raw.filter(l_freq=6, h_freq=40)
    
    #events
    events = events_from_annot
    
    #epochs
    tmin, tmax = -0.2, 0.5
    event_id = {'Auditory/Left': 2, 'Auditory/Right': 3}

    baseline = (None, 0.0)
    epochs = mne.Epochs(raw, events=events, event_id=event_id, tmin=tmin,
                        tmax=tmax, baseline=baseline,
                        picks=('eeg'))  # only include EEG
    picks = mne.pick_types(epochs.info, meg=False, eeg=True)
    evoked_left = epochs['Auditory/Left'].average(picks=picks)
    evoked_right = epochs['Auditory/Right'].average(picks=picks)
    left_data = evoked_left.data
    right_data = evoked_right.data
    
    return left_data, right_data

# %%
left_fist = []
right_fist = []
both_fist = []
both_feet = []
left_right_fist = [3, 4, 7, 8, 11, 12]
for i in range(1,110):
    for j in range(3,14):
        if i != 88 and i != 92 and i != 100:
            x, y = data_fetch(i, j)
            print(i, j, '___________________________________________________________________________________')
            if j in left_right_fist:
                left_fist.append(x)
                right_fist.append(y)
            else:
                both_fist.append(x)
                both_feet.append(y)
# Out:
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# ...

# %%
left_fist = np.array(left_fist)
right_fist = np.array(right_fist)
both_fist = np.array(both_fist)
both_feet = np.array(both_feet)
print(left_fist.shape)
both_feet.shape
# Out:
# (636, 64, 113)
# (530, 64, 113)

# %%
plt.plot(scipy.signal.welch(left_fist)[1][90][8])
plt.plot(scipy.signal.welch(right_fist)[1][90][8])
#plt.plot(both_fist[0][0])
#plt.plot(both_feet[0][0])

# %%
print(np.sum(left_fist[0][0] - right_fist[0][0]))
print(np.sum(left_fist[0][0] - both_fist[0][0]))
print(np.sum(left_fist[0][0] - both_feet[0][0]))
print(np.sum(both_feet[0][0] - both_fist[0][0]))
# Out:
# -6.85335950086766e-07
# -1.6039158473338307e-05
# -3.0591367277883554e-05
# 1.4552208804545274e-05

# %%
-6.85335950086766e-07
# Out:
# -6.85335950086766e-07

# %%
events = np.zeros((2332,4))
ones = np.ones((636,))
ones1 = np.ones((530,))

# %%
# left fist
events[:636,0] = events[:636,0] + ones
# right fist
events[636:1272,1] = events[636:1272,1] + ones
# both fist 
events[1272:1802,2] = events[1272:1802,2] + ones1
# both feet
events[1802:2332,3] = events[1802:2332,3] + ones1

# %%
def preprocessing(data):
    mean = np.mean(data, axis = 0)    
    var = np.var(data, axis = 0)
    data = (data - mean)/var
    return data
#data_array = preprocessing(data)

# %%
.left_fist1 = left_fist.reshape((636, 7232))
left_fist1 = preprocessing(left_fist1)
right_fist1 = right_fist.reshape((636, 7232))
right_fist1 = preprocessing(right_fist1)

# %%
both_fist1 = both_fist.reshape((530, 7232))
both_fist1 = preprocessing(both_fist1)
both_feet1 = both_feet.reshape((530, 7232))
both_feet1 = preprocessing(both_feet1)

# %%
# fast fourier transform

# %%
f_left_fist = np.fft.fft(left_fist).real.reshape((636,7232))
f_right_fist = np.fft.fft(right_fist).real.reshape((636,7232))
f_both_fist = np.fft.fft(both_fist).real.reshape((530,7232))
f_both_feet = np.fft.fft(both_feet).real.reshape((530,7232))

# %%
f_left_fist = preprocessing(f_left_fist)
f_right_fist = preprocessing(f_right_fist)
f_both_fist = preprocessing(f_both_fist)
f_btoh_feet = preprocessing(f_both_feet)

# %%
# Power Spectral Density

# %%
import scipy
_,psd_left_fist = scipy.signal.welch(left_fist)
_,psd_right_fist = scipy.signal.welch(right_fist)
_,psd_both_fist = scipy.signal.welch(both_fist)
_,psd_both_feet = scipy.signal.welch(both_feet)
# Out:
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\scipy\signal\spectral.py:1969: UserWarning: nperseg = 256 is greater than input length  = 113, using nperseg = 113
#   .format(nperseg, input_length))

# %%
psd_left_fist = psd_left_fist.reshape((636, 3648))
psd_right_fist = psd_right_fist.reshape((636, 3648))
psd_both_fist = psd_both_fist.reshape((530, 3648))
psd_both_feet = psd_both_feet.reshape((530, 3648))

# %%
# Concatenate

# %%
left_fist_data = np.concatenate((left_fist1, f_left_fist), axis = 1)
left_fist_data = np.concatenate((left_fist_data, psd_left_fist), axis = 1)
left_fist_data.shape
# Out:
# (636, 18112)

# %%
right_fist_data = np.concatenate((right_fist1, f_right_fist), axis = 1)
right_fist_data = np.concatenate((right_fist_data, psd_right_fist), axis = 1)
right_fist_data.shape
# Out:
# (636, 18112)

# %%
both_fist_data = np.concatenate((both_fist1, f_both_fist), axis = 1)
both_fist_data = np.concatenate((both_fist_data, psd_both_fist), axis = 1)
both_fist_data.shape
# Out:
# (530, 18112)

# %%
both_feet_data = np.concatenate((both_feet1, f_both_feet), axis = 1)
both_feet_data = np.concatenate((both_feet_data, psd_both_feet), axis = 1)
both_feet_data.shape
# Out:
# (530, 18112)

# %%
data = np.concatenate((left_fist_data, right_fist_data), axis = 0)
data = np.concatenate((data, both_fist_data), axis = 0)
data = np.concatenate((data, both_feet_data), axis = 0)
data.shape
# Out:
# (2332, 18112)

# %%
new_data = data.reshape((2332, 18112, 1))
events.shape
# Out:
# (2332, 4)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import StandardScaler # Used for scaling of data
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import metrics
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Conv1D, Conv2D, LSTM
from tensorflow.keras.layers import MaxPooling1D, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, BatchNormalization

# %%
x_train, x_test, y_train, y_test = train_test_split(new_data, events, test_size=0.2, random_state=42)
x_train.shape
# Out:
# (1865, 18112, 1)

# %%
def create_model():
    # create model
    model = Sequential()
    model.add(Conv1D(filters=15, kernel_size=3, activation='relu', input_shape=(18112,1)))
    model.add(Conv1D(filters=15, kernel_size=3, activation='relu'))
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(Dense(100, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(150, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.3))
    model.add(BatchNormalization())
    model.add(Dense(120, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(15, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(4, activation='softmax'))


    # Compile model
    model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['acc'])
    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_2 (Conv1D)            (None, 18110, 15)         60
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 18108, 15)         690
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 18108, 15)         0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 9054, 15)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 135810)            0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               13581100
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100)               0
# ...

# %%
history = model.fit(x_train, y_train, validation_data = (x_test, y_test), epochs=50)
# Out:
# Train on 1865 samples, validate on 467 samples
# Epoch 1/50
# 1865/1865 [==============================] - 75s 40ms/sample - loss: 1.4426 - acc: 0.3571 - val_loss: 1.1662 - val_acc: 0.5203
# Epoch 2/50
# 1865/1865 [==============================] - 64s 34ms/sample - loss: 1.0826 - acc: 0.4670 - val_loss: 0.9150 - val_acc: 0.5439
# Epoch 3/50
# 1865/1865 [==============================] - 61s 33ms/sample - loss: 0.9883 - acc: 0.4981 - val_loss: 0.8914 - val_acc: 0.4989
# Epoch 4/50
# 1865/1865 [==============================] - 62s 33ms/sample - loss: 0.9848 - acc: 0.4611 - val_loss: 0.8642 - val_acc: 0.5375
# Epoch 5/50
# 1865/1865 [==============================] - 60s 32ms/sample - loss: 0.9476 - acc: 0.4938 - val_loss: 0.8559 - val_acc: 0.5139
# Epoch 6/50
# 1865/1865 [==============================] - 61s 33ms/sample - loss: 0.9289 - acc: 0.5035 - val_loss: 0.8623 - val_acc: 0.4904
# Epoch 7/50
# ...

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
model.save('bci_motor_imaginary.h5')

# %%
raw_test = mne.io.read_raw_edf('C:/Users/Pushkar Khetrapal/Documents/BCI/files/S001/S001R04.edf', preload = True)
raw_test.rename_channels(lambda s: s.strip('.'))
events_from_annot, event_dict = mne.events_from_annotations(raw_test)
raw_test.set_eeg_reference("average", projection = True)
montage = mne.channels.read_montage("standard_1020")
raw_test.set_montage(montage)
raw_test.filter(l_freq=6, h_freq=40)
# Out:
# Extracting EDF parameters from C:\Users\Pushkar Khetrapal\Documents\BCI\files\S001\S001R04.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 6 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 6.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 5.00 Hz)
# - Upper passband edge: 40.00 Hz
# ...

# %%
events_from_annot
# Out:
# array([[    0,     0,     1],
#        [  672,     0,     3],
#        [ 1328,     0,     1],
#        [ 2000,     0,     2],
#        [ 2656,     0,     1],
#        [ 3328,     0,     2],
#        [ 3984,     0,     1],
#        [ 4656,     0,     3],
#        [ 5312,     0,     1],
#        [ 5984,     0,     3],
#        [ 6640,     0,     1],
#        [ 7312,     0,     2],
#        [ 7968,     0,     1],
#        [ 8640,     0,     3],
#        [ 9296,     0,     1],
#        [ 9968,     0,     2],
#        [10624,     0,     1],
#        [11296,     0,     3],
#        [11952,     0,     1],
#        [12624,     0,     2],
#        [13280,     0,     1],
#        [13952,     0,     2],
#        [14608,     0,     1],
#        [15280,     0,     3],
#        [15936,     0,     1],
#        [16608,     0,     2],
#        [17264,     0,     1],
#        [17936,     0,     3],
#        [18592,     0,     1],
#        [19264,     0,     2]])

# %%
test_data = raw_test.get_data()

# %%
test_data = test_data[:,events_from_annot[3][0]-32:events_from_annot[3][0]+81]

# %%
test_data.shape
# Out:
# (64, 113)

# %%
test_data1 = test_data.reshape((1,7232))
test_data1 = preprocessing(test_data1)
# Out:
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
test_data2 = np.fft.fft(test_data).real.reshape((1,7232))
test_data2 = preprocessing(test_data2)
# Out:
# c:\users\pushkar khetrapal\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
_,psd_test = scipy.signal.welch(test_data)
psd_test = psd_test.reshape((1, 3648))

# %%
tdata = np.concatenate((test_data1, test_data2), axis = 1)
tdata = np.concatenate((tdata, psd_test), axis = 1)
tdata.shape
# Out:
# (1, 18112)

# %%
tdata = tdata.reshape((18112, 1))

# %%
model.predict(aaa)
# Out:
# array([[1.5523903e-03, 7.5171777e-04, 9.9760675e-01, 8.9120600e-05]],
#       dtype=float32)

# %%
aaa = new_data[1500]

# %%
aaa = aaa.reshape((1, 18112, 1))

# %%
tdata
# Out:
# array([[           nan],
#        [           nan],
#        [           nan],
#        ...,
#        [8.57619249e-20],
#        [4.59099722e-18],
#        [7.67139276e-19]])
